# %% [markdown]
# <a href="https://colab.research.google.com/github/power777-coder/DADV/blob/main/DADV_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data = pd.read_excel("/content/Car Inventory_DADV_2024.xlsx")

# %%
Data.head()  #top 5 rows
# Out:
#    Unnamed: 0    Make    Model   Color  Mileage  Price  Cost
# 0         NaN   Honda   Accord  Silver   101354     20    15
# 1         NaN  Toyota    Camry   Black    75006     25    20
# 2         NaN  Nissan   Altima   Green    69847     30    30
# 3         NaN  Nissan   Altima   Green    55233     30    25
# 4         NaN  Toyota  Corolla   Black    87278     30    20

# %%
Data.head(8)
# Out:
#    Unnamed: 0    Make    Model   Color  Mileage  Price  Cost
# 0         NaN   Honda   Accord  Silver   101354     20    15
# 1         NaN  Toyota    Camry   Black    75006     25    20
# 2         NaN  Nissan   Altima   Green    69847     30    30
# 3         NaN  Nissan   Altima   Green    55233     30    25
# 4         NaN  Toyota  Corolla   Black    87278     30    20
# 5         NaN  Toyota  Corolla    Blue   130684     20    15
# 6         NaN  Toyota  Corolla  Silver    59169    250    27
# 7         NaN   Honda    Civic   White   138789     20    10

# %%
Data.tail() #last 5 rows
# Out:
#     Unnamed: 0    Make    Model   Color  Mileage  Price  Cost
# 17         NaN  Nissan   Maxima     Red   101856     30    25
# 18         NaN    Ford   Fusion   Black    42542     25    20
# 19         NaN   Dodge  Charger  Silver    34853     45    35
# 20         NaN   Dodge  Charger  Silver    58173     45    40
# 21         NaN   Dodge  Charger   Black   136775     20    18

# %%
Data.tail(8)
# Out:
#     Unnamed: 0    Make    Model   Color  Mileage  Price  Cost
# 14         NaN    Ford   Escape     Red    40826     40    40
# 15         NaN    Ford  Mustang  Silver    41560     30    30
# 16         NaN   Honda      CRV    Blue    49326     50    40
# 17         NaN  Nissan   Maxima     Red   101856     30    25
# 18         NaN    Ford   Fusion   Black    42542     25    20
# 19         NaN   Dodge  Charger  Silver    34853     45    35
# 20         NaN   Dodge  Charger  Silver    58173     45    40
# 21         NaN   Dodge  Charger   Black   136775     20    18

# %%
Data.shape #total no. of rows and column
# Out:
# (22, 7)

# %%
Data.info
# Out:
# <bound method DataFrame.info of     Unnamed: 0       Make      Model   Color  Mileage  Price  Cost
# 0          NaN      Honda     Accord  Silver   101354     20    15
# 1          NaN     Toyota      Camry   Black    75006     25    20
# 2          NaN     Nissan     Altima   Green    69847     30    30
# 3          NaN     Nissan     Altima   Green    55233     30    25
# 4          NaN     Toyota    Corolla   Black    87278     30    20
# 5          NaN     Toyota    Corolla    Blue   130684     20    15
# 6          NaN     Toyota    Corolla  Silver    59169    250    27
# 7          NaN      Honda      Civic   White   138789     20    10
# 8          NaN       Ford      F-150   Black    89073     30    30
# 9          NaN  Chevrolet  Silverado   Green   109231     40    35
# 10         NaN  Chevrolet     Impala  Silver    87675     50    35
# 11         NaN  Chevrolet     Impala   White   140811     20    10
# 12         NaN  Chevrolet     Malibu   White   139300     25    10
# ...

# %%
Data.isnull().sum()
# Out:
# Unnamed: 0    22
# Make           0
# Model          0
# Color          0
# Mileage        0
# Price          0
# Cost           0
# dtype: int64

# %%
Data.nunique()
# Out:
# Unnamed: 0     0
# Make           6
# Model         15
# Color          6
# Mileage       22
# Price          7
# Cost           9
# dtype: int64
