# %% [markdown]
# <a href="https://colab.research.google.com/github/power777-coder/DADV/blob/main/DADV_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv("/content/homeprices.csv")

# %%
data
# Out:
#    area   price
# 0  2600  550000
# 1  2800  575000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
data.shape
# Out:
# (5, 2)

# %%
data.isnull().sum()
# Out:
# area     0
# price    0
# dtype: int64

# %%
data.corr()
# Out:
#            area     price
# area   1.000000  0.994697
# price  0.994697  1.000000

# %%
p=data.drop("price",axis=1)
p
# Out:
#    area
# 0  2600
# 1  2800
# 2  3200
# 3  3600
# 4  4000

# %%
q=data["price"]
q
# Out:
# 0    550000
# 1    575000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
print("p shape is : ",p.shape)
print("q shape is : ",q.shape)
# Out:
# p shape is :  (5, 1)
# q shape is :  (5,)

# %%
plt.scatter(p,q)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(p,q,test_size=0.30,shuffle=True,random_state=40)
print("x shape is : ",x_train.shape)
print("x shape is : ",x_test.shape)
print("y shape is : ",y_train.shape)
print("y shape is : ",x_test.shape)
# Out:
# x shape is :  (3, 1)
# x shape is :  (2, 1)
# y shape is :  (3,)
# y shape is :  (2, 1)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.plot(x_train,y_train,'bo')

# %%
plt.plot(x_test,y_test,'ro')

# %%
y_pred=model.predict(x_test)
plt.plot(y_pred,y_test,'ro')
plt.plot(y_test,y_test,'b-')

# %%
model.score(x_test,y_test)
# Out:
# 0.8496138038548744

# %%
model.predict([[3300]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([639017.85714286])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.8496138038548744

# %%
t=model.coef_

# %%
u=model.intercept_

# %%
x=t*3300+u

# %%
sns.lmplot(data=data,x='area',y='price')
